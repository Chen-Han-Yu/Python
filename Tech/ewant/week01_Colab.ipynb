# %% [markdown]
# # 上課影片內容
# [課程參考] (https://www.ewant.org/admin/tool/mooccourse/mnetcourseinfo.php?hostid=10&id=4549)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 切點
x = np.linspace(-2,2,5)
x
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
y = x**2
y
# Out:
# array([4., 1., 0., 1., 4.])

# %%
plt.plot(x,y)

# %%
x = np.linspace(-2,2,500)
y = x**2
plt.plot(x,y)

# %%
# 加入卡通圖案
plt.xkcd()
plt.plot(x,y)

# %% [markdown]
# # 作業一：程式作業—畫個函數圖形吧!
# > OpenDate:2021-09-30<br>
# > Content:深度學習的原理及實務上的應用（2021秋季班）作業<br>
# > Author:柴犬陪唸書 <br>
# # 套件
# - numpy
#   - linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
#   - cos(x),sin(x)
# - matplotlib
#   - vlines(x, ymin, ymax, colors, linestyles)
#   - hlines(y, xmin, xmax, colors, linestyles)
# # Reference
# 1. [如何在 Matplotlib 中繪製水平和垂直線](https://www.delftstack.com/zh-tw/howto/matplotlib/how-to-plot-horizontal-and-vertical-line-in-matplotlib/)
# 2. [頭頂數學式參考 ISBN:9789863124375](https://24h.pchome.com.tw/books/prod/DJAA2V-A90083511)

# %%
x1 = np.linspace(-9,9,100)
x2 = np.linspace(-1,1,5)
# 頭頂
y1 = x1*x1*np.cos(x1)+ 77.30155121
# 下巴
y2 = x1**2/2-160
# 嘴巴
y3 = -(x2*1.5)**2-80
# 畫頭頂下巴嘴巴
plt.plot(x1,y1,"k",x1,y2,"k",x2,y3,"k")
# 畫鼻子
plt.plot(np.cos(x1),10*np.sin(x1),"k")
# 畫右眼
plt.plot(np.cos(x1)+5,15*np.sin(x1)+25,"k")
plt.plot(1.2*np.cos(x1)+5,20*np.sin(x1)+25,"k")
# 畫左眼
plt.plot(np.cos(x1)-5,15*np.sin(x1)+25,"k")
plt.plot(1.2*np.cos(x1)-5,20*np.sin(x1)+25,"k")
# 畫左鬍鬚
plt.hlines(-25,-9,-7,"r")
plt.hlines(-25,7,9,"r")
plt.text(-2,100,"Facepalm")
plt.show()
